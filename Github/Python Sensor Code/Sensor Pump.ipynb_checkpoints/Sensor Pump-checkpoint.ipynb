# %%
import paho.mqtt.client as mqtt
import time
import random

BROKER = "broker.hivemq.com"  # ganti ke broker lokal kalau mau
PORT = 1883

client = mqtt.Client(client_id="pump-sensor-01", protocol=mqtt.MQTTv311, transport="tcp", userdata=None, clean_session=True)

client.connect(BROKER, PORT, 60)

while True:
    pressure = round(random.uniform(2.5, 3.5), 2)
    flow = round(random.uniform(100, 150), 1)
    status = random.choice(["ON", "OFF"])

    client.publish("pump/1/pressure", pressure)
    client.publish("pump/1/flow", flow)
    client.publish("pump/1/status", status)

    print(f"Published: Pressure={pressure} bar | Flow={flow} L/min | Status={status}")
    time.sleep(5)  # kirim tiap 5 detik
# Out:
# C:\Users\KIM\AppData\Local\Temp\ipykernel_3144\460988047.py:8: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client(client_id="pump-sensor-01", protocol=mqtt.MQTTv311, transport="tcp", userdata=None, clean_session=True)
# Published: Pressure=2.71 bar | Flow=115.7 L/min | Status=OFF
# Published: Pressure=3.1 bar | Flow=111.1 L/min | Status=OFF
# Published: Pressure=2.94 bar | Flow=117.4 L/min | Status=OFF
# Published: Pressure=3.05 bar | Flow=144.7 L/min | Status=OFF
# Published: Pressure=2.91 bar | Flow=106.6 L/min | Status=ON
# Published: Pressure=2.99 bar | Flow=134.4 L/min | Status=OFF
# Published: Pressure=2.98 bar | Flow=110.5 L/min | Status=ON
# Published: Pressure=3.44 bar | Flow=110.7 L/min | Status=OFF
# Published: Pressure=3.37 bar | Flow=129.6 L/min | Status=ON
# Published: Pressure=3.25 bar | Flow=112.6 L/min | Status=ON
# Published: Pressure=3.39 bar | Flow=144.6 L/min | Status=ON
# Published: Pressure=2.69 bar | Flow=136.3 L/min | Status=ON
# Published: Pressure=2.69 bar | Flow=118.7 L/min | Status=ON
# Published: Pressure=2.62 bar | Flow=114.7 L/min | Status=ON
# Published: Pressure=2.8 bar | Flow=137.3 L/min | Status=OFF
# Published: Pressure=3.31 bar | Flow=114.7 L/min | Status=ON
# Published: Pressure=3.5 bar | Flow=137.4 L/min | Status=ON
# Published: Pressure=3.29 bar | Flow=106.9 L/min | Status=OFF
# Published: Pressure=2.68 bar | Flow=135.2 L/min | Status=ON
# Published: Pressure=3.12 bar | Flow=143.8 L/min | Status=ON
# Published: Pressure=3.25 bar | Flow=117.5 L/min | Status=OFF
# Published: Pressure=2.87 bar | Flow=127.8 L/min | Status=OFF
# Published: Pressure=2.57 bar | Flow=137.9 L/min | Status=OFF
# Published: Pressure=2.95 bar | Flow=115.4 L/min | Status=OFF
# Published: Pressure=2.55 bar | Flow=129.8 L/min | Status=OFF
# Published: Pressure=3.33 bar | Flow=131.7 L/min | Status=OFF
# Published: Pressure=2.58 bar | Flow=117.0 L/min | Status=OFF
# Published: Pressure=3.04 bar | Flow=127.3 L/min | Status=ON
# Published: Pressure=3.34 bar | Flow=101.4 L/min | Status=ON
# Published: Pressure=3.34 bar | Flow=114.4 L/min | Status=OFF
# Published: Pressure=3.5 bar | Flow=121.8 L/min | Status=OFF
# Published: Pressure=3.27 bar | Flow=117.1 L/min | Status=OFF
# Published: Pressure=2.95 bar | Flow=101.8 L/min | Status=OFF
# Published: Pressure=2.87 bar | Flow=109.0 L/min | Status=OFF
# Published: Pressure=3.49 bar | Flow=123.2 L/min | Status=ON
# Published: Pressure=3.35 bar | Flow=100.3 L/min | Status=ON
# Published: Pressure=3.04 bar | Flow=120.3 L/min | Status=ON
# Published: Pressure=2.63 bar | Flow=138.6 L/min | Status=ON
# Published: Pressure=3.21 bar | Flow=141.2 L/min | Status=ON
# Published: Pressure=2.59 bar | Flow=137.9 L/min | Status=ON
# Published: Pressure=2.99 bar | Flow=138.7 L/min | Status=ON
# Published: Pressure=3.19 bar | Flow=112.5 L/min | Status=ON
# Published: Pressure=3.32 bar | Flow=128.0 L/min | Status=ON
# Published: Pressure=3.09 bar | Flow=146.3 L/min | Status=ON
# Published: Pressure=3.41 bar | Flow=129.9 L/min | Status=OFF
# Published: Pressure=3.03 bar | Flow=131.5 L/min | Status=OFF
# Published: Pressure=3.45 bar | Flow=146.6 L/min | Status=OFF
# Published: Pressure=3.24 bar | Flow=144.2 L/min | Status=OFF
# Published: Pressure=2.53 bar | Flow=144.5 L/min | Status=OFF
# Published: Pressure=2.75 bar | Flow=127.5 L/min | Status=ON
# Published: Pressure=2.9 bar | Flow=134.5 L/min | Status=OFF
# Published: Pressure=3.07 bar | Flow=126.0 L/min | Status=ON
# Published: Pressure=2.94 bar | Flow=104.2 L/min | Status=ON
# Published: Pressure=2.81 bar | Flow=115.1 L/min | Status=ON
# Published: Pressure=3.36 bar | Flow=145.2 L/min | Status=OFF
# Published: Pressure=2.71 bar | Flow=148.1 L/min | Status=OFF
# Published: Pressure=3.37 bar | Flow=105.1 L/min | Status=OFF
# Published: Pressure=3.01 bar | Flow=138.4 L/min | Status=OFF
# Published: Pressure=3.43 bar | Flow=131.2 L/min | Status=ON
# Published: Pressure=2.88 bar | Flow=105.7 L/min | Status=ON
# Published: Pressure=2.61 bar | Flow=108.5 L/min | Status=OFF
# Published: Pressure=2.57 bar | Flow=135.6 L/min | Status=ON
# Published: Pressure=3.02 bar | Flow=115.8 L/min | Status=OFF
# Published: Pressure=3.42 bar | Flow=148.7 L/min | Status=OFF
# Published: Pressure=3.42 bar | Flow=120.6 L/min | Status=ON
# Published: Pressure=3.21 bar | Flow=100.5 L/min | Status=OFF
# Published: Pressure=2.95 bar | Flow=142.3 L/min | Status=OFF
# Published: Pressure=2.57 bar | Flow=114.2 L/min | Status=ON
# Published: Pressure=2.91 bar | Flow=132.8 L/min | Status=OFF
# Published: Pressure=3.09 bar | Flow=101.3 L/min | Status=OFF
# Published: Pressure=3.0 bar | Flow=109.1 L/min | Status=OFF
# Published: Pressure=2.78 bar | Flow=116.5 L/min | Status=OFF
# Published: Pressure=2.9 bar | Flow=129.1 L/min | Status=ON
# Published: Pressure=3.49 bar | Flow=149.5 L/min | Status=OFF
# Published: Pressure=3.03 bar | Flow=145.6 L/min | Status=ON
# Published: Pressure=2.55 bar | Flow=113.3 L/min | Status=OFF
# Published: Pressure=2.99 bar | Flow=112.5 L/min | Status=OFF
# Published: Pressure=3.18 bar | Flow=141.4 L/min | Status=ON
# Published: Pressure=2.97 bar | Flow=119.7 L/min | Status=OFF
# Published: Pressure=3.04 bar | Flow=131.9 L/min | Status=OFF
# Published: Pressure=2.61 bar | Flow=124.6 L/min | Status=OFF
# Published: Pressure=3.35 bar | Flow=117.1 L/min | Status=ON
# Published: Pressure=2.74 bar | Flow=123.1 L/min | Status=ON
# Published: Pressure=3.42 bar | Flow=101.5 L/min | Status=OFF
# Published: Pressure=3.2 bar | Flow=117.0 L/min | Status=ON
# Published: Pressure=3.21 bar | Flow=143.2 L/min | Status=ON
# Published: Pressure=2.75 bar | Flow=123.0 L/min | Status=ON
# Published: Pressure=3.24 bar | Flow=125.7 L/min | Status=ON
# Published: Pressure=3.08 bar | Flow=115.7 L/min | Status=ON
# Published: Pressure=3.02 bar | Flow=109.9 L/min | Status=ON
# Published: Pressure=3.48 bar | Flow=123.8 L/min | Status=ON
# Published: Pressure=2.5 bar | Flow=132.9 L/min | Status=OFF
# Published: Pressure=3.29 bar | Flow=144.5 L/min | Status=ON
# Published: Pressure=2.94 bar | Flow=117.4 L/min | Status=ON
# Published: Pressure=2.92 bar | Flow=118.1 L/min | Status=ON
# Published: Pressure=2.74 bar | Flow=148.7 L/min | Status=OFF
# Published: Pressure=3.19 bar | Flow=149.7 L/min | Status=OFF
# Published: Pressure=2.97 bar | Flow=113.7 L/min | Status=ON
# Published: Pressure=3.12 bar | Flow=118.7 L/min | Status=OFF
# Published: Pressure=2.54 bar | Flow=144.0 L/min | Status=ON
# Published: Pressure=3.37 bar | Flow=126.9 L/min | Status=OFF
# Published: Pressure=2.98 bar | Flow=102.5 L/min | Status=ON
# Published: Pressure=3.3 bar | Flow=124.3 L/min | Status=ON
# Published: Pressure=2.83 bar | Flow=103.8 L/min | Status=ON
# Published: Pressure=3.4 bar | Flow=132.6 L/min | Status=ON
# Published: Pressure=2.72 bar | Flow=138.7 L/min | Status=ON
# Published: Pressure=2.94 bar | Flow=126.4 L/min | Status=OFF
# Published: Pressure=2.69 bar | Flow=127.9 L/min | Status=OFF
# Published: Pressure=3.41 bar | Flow=141.7 L/min | Status=OFF
# Published: Pressure=2.8 bar | Flow=138.3 L/min | Status=OFF
# Published: Pressure=2.74 bar | Flow=147.7 L/min | Status=ON
# Published: Pressure=3.37 bar | Flow=122.7 L/min | Status=ON
# Published: Pressure=3.03 bar | Flow=127.8 L/min | Status=ON
# Published: Pressure=3.07 bar | Flow=146.3 L/min | Status=ON
# Published: Pressure=2.59 bar | Flow=145.6 L/min | Status=OFF
# Published: Pressure=3.24 bar | Flow=132.9 L/min | Status=OFF
# Published: Pressure=3.0 bar | Flow=145.5 L/min | Status=ON
# Published: Pressure=3.41 bar | Flow=144.8 L/min | Status=ON
# Published: Pressure=3.24 bar | Flow=120.0 L/min | Status=ON
# Published: Pressure=2.86 bar | Flow=123.4 L/min | Status=ON
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 22
#      19 client.publish("pump/1/status", status)
#      21 print(f"Published: Pressure={pressure} bar | Flow={flow} L/min | Status={status}")
# ---> 22 time.sleep(5)
#
# KeyboardInterrupt:
